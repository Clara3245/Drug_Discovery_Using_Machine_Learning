# %% [markdown]
# # **Bioinformatics Project - Part 1 Computational Drug Discovery Data Concised**
#
# In this Notebook I will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (0.10.9)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.18.4->chembl_webresource_client) (2019.11.28)
# Requirement already satisfied: attrs>=21.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-cache~=1.2->chembl_webresource_client) (24.3.0)
# Requirement already satisfied: cattrs>=22.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Requirement already satisfied: url-normalize>=1.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /Users/clara/Library/Python/3.8/lib/python/site-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.14.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for pancreas**

# %%
# Target search for pancreas
target = new_client.target
target_query = target.search('pancreas')
targets = pd.DataFrame.from_dict(target_query)
targets.head(10)
# Out:
#   cross_references           organism                       pref_name  score  \
# 0               []       Mus musculus                        Pancreas   19.0
# 1               []  Rattus norvegicus                        Pancreas   19.0
# 2               []       Homo sapiens              Carboxypeptidase B   18.0
# 3               []       Homo sapiens                    Kallikrein 1   17.0
# 4               []       Homo sapiens  Protein disulfide-isomerase A2   17.0
# 5               []       Homo sapiens                        Tryptase    6.0
# 6               []       Homo sapiens                         Trypsin    6.0
# 7               []         Sus scrofa             Pancreatic elastase    6.0
# 8               []       Homo sapiens              Thrombin & trypsin    6.0
# 9               []       Homo sapiens    Coagulation factor VII and X    6.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613587
# 1               False     CHEMBL613650
# 2               False       CHEMBL2552
# 3               False       CHEMBL2319
# 4               False    CHEMBL4739853
# 5               False    CHEMBL2095193
# 6               False    CHEMBL2095204
# 7               False    CHEMBL2096984
# 8               False    CHEMBL2096988
# 9               False    CHEMBL2111412
#
#                                    target_components        target_type  \
# 0                                                 []             TISSUE
# 1                                                 []             TISSUE
# 2  [{'accession': 'P15086', 'component_descriptio...     SINGLE PROTEIN
# 3  [{'accession': 'P06870', 'component_descriptio...     SINGLE PROTEIN
# 4  [{'accession': 'Q13087', 'component_descriptio...     SINGLE PROTEIN
# 5  [{'accession': 'Q9BZJ3', 'component_descriptio...     PROTEIN FAMILY
# 6  [{'accession': 'P07477', 'component_descriptio...     PROTEIN FAMILY
# 7  [{'accession': 'P08419', 'component_descriptio...     PROTEIN FAMILY
# 8  [{'accession': 'P00734', 'component_descriptio...  SELECTIVITY GROUP
# 9  [{'accession': 'P00742', 'component_descriptio...  SELECTIVITY GROUP
#
#    tax_id
# 0   10090
# 1   10116
# 2    9606
# 3    9606
# 4    9606
# 5    9606
# 6    9606
# 7    9823
# 8    9606
# 9    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human pancreas* (seventh entry)**

# %% [markdown]
# We will assign the seventhth entry (which corresponds to the target protein, *Human Pancreatic lipase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL2095204'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Pancreatic lipase* (CHEMBL2095204) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     action_type activity_comment  activity_id  \
# 0          None             None        34309
# 1          None             None        34315
# 2          None             None        37941
# 3          None             None        40292
# 4          None             None        40298
# ..          ...              ...          ...
# 493        None             None     25588137
# 494        None             None     25588138
# 495        None             None     25637648
# 496        None             None     25702988
# 497        None             None     25702989
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL815474
# 1                                                   []    CHEMBL815474
# 2                                                   []    CHEMBL815474
# 3                                                   []    CHEMBL815474
# 4                                                   []    CHEMBL815474
# ..                                                 ...             ...
# 493  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5355157
# 494  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5355157
# 495  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5367462
# 496  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5385455
# 497  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5385455
#
#                                      assay_description assay_type  \
# 0               Binding affinity against human trypsin          B
# 1               Binding affinity against human trypsin          B
# 2               Binding affinity against human trypsin          B
# 3               Binding affinity against human trypsin          B
# 4               Binding affinity against human trypsin          B
# ..                                                 ...        ...
# 493  Inhibition of trypsin (unknown origin) using S...          B
# 494  Inhibition of trypsin (unknown origin) using S...          B
# 495  Inhibition of human plasma trypsin using Boc-I...          B
# 496  Inhibition of human recombinant trypsin using ...          B
# 497  Inhibition of human recombinant trypsin using ...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000190  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000190  ...
# ..                      ...                    ...          ...  ...
# 493                    None                   None  BAO_0000190  ...
# 494                    None                   None  BAO_0000190  ...
# 495                    None                   None  BAO_0000190  ...
# 496                    None                   None  BAO_0000190  ...
# 497                    None                   None  BAO_0000190  ...
#
#     target_organism target_pref_name target_tax_id text_value  toid  type  \
# 0      Homo sapiens          Trypsin          9606       None  None  IC50
# 1      Homo sapiens          Trypsin          9606       None  None  IC50
# 2      Homo sapiens          Trypsin          9606       None  None  IC50
# 3      Homo sapiens          Trypsin          9606       None  None  IC50
# 4      Homo sapiens          Trypsin          9606       None  None  IC50
# ..              ...              ...           ...        ...   ...   ...
# 493    Homo sapiens          Trypsin          9606       None  None  IC50
# 494    Homo sapiens          Trypsin          9606       None  None  IC50
# 495    Homo sapiens          Trypsin          9606       None  None  IC50
# 496    Homo sapiens          Trypsin          9606       None  None  IC50
# 497    Homo sapiens          Trypsin          9606       None  None  IC50
#
#     units    uo_units upper_value    value
# 0      uM  UO_0000065        None     10.0
# 1      uM  UO_0000065        None     10.0
# 2      uM  UO_0000065        None     10.0
# 3      uM  UO_0000065        None     10.0
# 4      uM  UO_0000065        None     10.0
# ..    ...         ...         ...      ...
# 493    uM  UO_0000065        None    100.0
# 494    uM  UO_0000065        None    100.0
# 495    uM  UO_0000065        None     50.0
# 496    uM  UO_0000065        None     30.0
# 497    nM  UO_0000065        None  30000.0
#
# [498 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('pancreaticlipase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** (potency of the drug, the lower the stronger the drug) and **canonical_smiles** column then drop it.

# %%
df2 = df.dropna(subset=['canonical_smiles', 'standard_value'])
df2
# Out:
#     action_type activity_comment  activity_id  \
# 0          None             None        34309
# 1          None             None        34315
# 2          None             None        37941
# 3          None             None        40292
# 4          None             None        40298
# ..          ...              ...          ...
# 493        None             None     25588137
# 494        None             None     25588138
# 495        None             None     25637648
# 496        None             None     25702988
# 497        None             None     25702989
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL815474
# 1                                                   []    CHEMBL815474
# 2                                                   []    CHEMBL815474
# 3                                                   []    CHEMBL815474
# 4                                                   []    CHEMBL815474
# ..                                                 ...             ...
# 493  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5355157
# 494  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5355157
# 495  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5367462
# 496  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5385455
# 497  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5385455
#
#                                      assay_description assay_type  \
# 0               Binding affinity against human trypsin          B
# 1               Binding affinity against human trypsin          B
# 2               Binding affinity against human trypsin          B
# 3               Binding affinity against human trypsin          B
# 4               Binding affinity against human trypsin          B
# ..                                                 ...        ...
# 493  Inhibition of trypsin (unknown origin) using S...          B
# 494  Inhibition of trypsin (unknown origin) using S...          B
# 495  Inhibition of human plasma trypsin using Boc-I...          B
# 496  Inhibition of human recombinant trypsin using ...          B
# 497  Inhibition of human recombinant trypsin using ...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000190  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000190  ...
# ..                      ...                    ...          ...  ...
# 493                    None                   None  BAO_0000190  ...
# 494                    None                   None  BAO_0000190  ...
# 495                    None                   None  BAO_0000190  ...
# 496                    None                   None  BAO_0000190  ...
# 497                    None                   None  BAO_0000190  ...
#
#     target_organism target_pref_name target_tax_id text_value  toid  type  \
# 0      Homo sapiens          Trypsin          9606       None  None  IC50
# 1      Homo sapiens          Trypsin          9606       None  None  IC50
# 2      Homo sapiens          Trypsin          9606       None  None  IC50
# 3      Homo sapiens          Trypsin          9606       None  None  IC50
# 4      Homo sapiens          Trypsin          9606       None  None  IC50
# ..              ...              ...           ...        ...   ...   ...
# 493    Homo sapiens          Trypsin          9606       None  None  IC50
# 494    Homo sapiens          Trypsin          9606       None  None  IC50
# 495    Homo sapiens          Trypsin          9606       None  None  IC50
# 496    Homo sapiens          Trypsin          9606       None  None  IC50
# 497    Homo sapiens          Trypsin          9606       None  None  IC50
#
#     units    uo_units upper_value    value
# 0      uM  UO_0000065        None     10.0
# 1      uM  UO_0000065        None     10.0
# 2      uM  UO_0000065        None     10.0
# 3      uM  UO_0000065        None     10.0
# 4      uM  UO_0000065        None     10.0
# ..    ...         ...         ...      ...
# 493    uM  UO_0000065        None    100.0
# 494    uM  UO_0000065        None    100.0
# 495    uM  UO_0000065        None     50.0
# 496    uM  UO_0000065        None     30.0
# 497    nM  UO_0000065        None  30000.0
#
# [476 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 469

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     action_type activity_comment  activity_id  \
# 0          None             None        34309
# 1          None             None        34315
# 2          None             None        37941
# 3          None             None        40292
# 4          None             None        40298
# ..          ...              ...          ...
# 493        None             None     25588137
# 494        None             None     25588138
# 495        None             None     25637648
# 496        None             None     25702988
# 497        None             None     25702989
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL815474
# 1                                                   []    CHEMBL815474
# 2                                                   []    CHEMBL815474
# 3                                                   []    CHEMBL815474
# 4                                                   []    CHEMBL815474
# ..                                                 ...             ...
# 493  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5355157
# 494  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5355157
# 495  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5367462
# 496  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5385455
# 497  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5385455
#
#                                      assay_description assay_type  \
# 0               Binding affinity against human trypsin          B
# 1               Binding affinity against human trypsin          B
# 2               Binding affinity against human trypsin          B
# 3               Binding affinity against human trypsin          B
# 4               Binding affinity against human trypsin          B
# ..                                                 ...        ...
# 493  Inhibition of trypsin (unknown origin) using S...          B
# 494  Inhibition of trypsin (unknown origin) using S...          B
# 495  Inhibition of human plasma trypsin using Boc-I...          B
# 496  Inhibition of human recombinant trypsin using ...          B
# 497  Inhibition of human recombinant trypsin using ...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000190  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000190  ...
# ..                      ...                    ...          ...  ...
# 493                    None                   None  BAO_0000190  ...
# 494                    None                   None  BAO_0000190  ...
# 495                    None                   None  BAO_0000190  ...
# 496                    None                   None  BAO_0000190  ...
# 497                    None                   None  BAO_0000190  ...
#
#     target_organism target_pref_name target_tax_id text_value  toid  type  \
# 0      Homo sapiens          Trypsin          9606       None  None  IC50
# 1      Homo sapiens          Trypsin          9606       None  None  IC50
# 2      Homo sapiens          Trypsin          9606       None  None  IC50
# 3      Homo sapiens          Trypsin          9606       None  None  IC50
# 4      Homo sapiens          Trypsin          9606       None  None  IC50
# ..              ...              ...           ...        ...   ...   ...
# 493    Homo sapiens          Trypsin          9606       None  None  IC50
# 494    Homo sapiens          Trypsin          9606       None  None  IC50
# 495    Homo sapiens          Trypsin          9606       None  None  IC50
# 496    Homo sapiens          Trypsin          9606       None  None  IC50
# 497    Homo sapiens          Trypsin          9606       None  None  IC50
#
#     units    uo_units upper_value    value
# 0      uM  UO_0000065        None     10.0
# 1      uM  UO_0000065        None     10.0
# 2      uM  UO_0000065        None     10.0
# 3      uM  UO_0000065        None     10.0
# 4      uM  UO_0000065        None     10.0
# ..    ...         ...         ...      ...
# 493    uM  UO_0000065        None    100.0
# 494    uM  UO_0000065        None    100.0
# 495    uM  UO_0000065        None     50.0
# 496    uM  UO_0000065        None     30.0
# 497    nM  UO_0000065        None  30000.0
#
# [469 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL337921  Cc1cc(NC(=O)Cc2ccc3[nH]c(-c4ccc(Cl)s4)nc3c2)cc...
# 1         CHEMBL340500  Cc1cc(NC(=O)Cc2ccc3[nH]c(-c4ccc(Cl)s4)nc3c2)cc...
# 2         CHEMBL124846  O=C(Cc1ccc2[nH]c(-c3ccc(Cl)s3)nc2c1)Nc1ccc(N2C...
# 3         CHEMBL331231  CS(=O)(=O)c1ccccc1-c1ccc(NC(=O)Cc2ccc3[nH]c(-c...
# 4         CHEMBL124705  O=C(Cc1ccc2[nH]c(-c3ccc(Cl)s3)nc2c1)Nc1ccc(N2C...
# ..                 ...                                                ...
# 493      CHEMBL5397791     COc1ccccc1C(=O)n1nc(-c2ccccn2)cc1NCc1ccc(Cl)s1
# 494      CHEMBL5425314  CC(C)(C)C(=O)n1nc(-c2ccc[nH]c2=O)cc1NCc1ccc(Cl)s1
# 495      CHEMBL3903980  O=C(Cn1c2c(c(-c3cccc(Cl)c3)cc1=O)C(=O)NC2)Nc1c...
# 496      CHEMBL5431053          Cc1ccccc1C(=O)N1CCN(c2ccc3c(N)nncc3c2)CC1
# 497      CHEMBL5417464  Cc1cc([C@H]2CN(c3cc(F)c4c(N)nncc4c3)CCN2c2cccc...
#
#     standard_value
# 0          10000.0
# 1          10000.0
# 2          10000.0
# 3          10000.0
# 4          10000.0
# ..             ...
# 493       100000.0
# 494       100000.0
# 495        50000.0
# 496        30000.0
# 497        30000.0
#
# [469 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('pancreaticlipase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('pancreaticlipase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL337921  Cc1cc(NC(=O)Cc2ccc3[nH]c(-c4ccc(Cl)s4)nc3c2)cc...
# 1         CHEMBL340500  Cc1cc(NC(=O)Cc2ccc3[nH]c(-c4ccc(Cl)s4)nc3c2)cc...
# 2         CHEMBL124846  O=C(Cc1ccc2[nH]c(-c3ccc(Cl)s3)nc2c1)Nc1ccc(N2C...
# 3         CHEMBL331231  CS(=O)(=O)c1ccccc1-c1ccc(NC(=O)Cc2ccc3[nH]c(-c...
# 4         CHEMBL124705  O=C(Cc1ccc2[nH]c(-c3ccc(Cl)s3)nc2c1)Nc1ccc(N2C...
# ..                 ...                                                ...
# 464      CHEMBL5397791     COc1ccccc1C(=O)n1nc(-c2ccccn2)cc1NCc1ccc(Cl)s1
# 465      CHEMBL5425314  CC(C)(C)C(=O)n1nc(-c2ccc[nH]c2=O)cc1NCc1ccc(Cl)s1
# 466      CHEMBL3903980  O=C(Cn1c2c(c(-c3cccc(Cl)c3)cc1=O)C(=O)NC2)Nc1c...
# 467      CHEMBL5431053          Cc1ccccc1C(=O)N1CCN(c2ccc3c(N)nncc3c2)CC1
# 468      CHEMBL5417464  Cc1cc([C@H]2CN(c3cc(F)c4c(N)nncc4c3)CCN2c2cccc...
#
#      standard_value     class
# 0           10000.0  inactive
# 1           10000.0  inactive
# 2           10000.0  inactive
# 3           10000.0  inactive
# 4           10000.0  inactive
# ..              ...       ...
# 464        100000.0  inactive
# 465        100000.0  inactive
# 466         50000.0  inactive
# 467         30000.0  inactive
# 468         30000.0  inactive
#
# [469 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('pancreaticlipase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip pancreaticlipase.zip *.csv
# Out:
#   adding: pancreaticlipase_01_bioactivity_data_raw.csv (deflated 91%)
#   adding: pancreaticlipase_02_bioactivity_data_preprocessed.csv (deflated 82%)
#   adding: pancreaticlipase_03_bioactivity_data_curated.csv (deflated 83%)

# %%
! ls -l
# Out:
# total 200304
# -rw-r--r--  1 clara  staff     97206 Jan 15 18:00 CDD_ML_Part1_Pancreaticlipase_Bioactivity_Data_Concised.ipynb
# -rw-r--r--  1 clara  staff    595910 Jan 15 17:50 CDD_ML_Part2_Pancreaticlipase_Exploratory_Data_Analysis.ipynb
# -rwxr-xr-x  1 clara  staff  85055499 Mar 11  2020 Miniconda3-py37_4.8.2-Linux-x86_64.sh
# -rw-r--r--  1 clara  staff        26 Jan 15 12:55 README.md
# drwxr-xr-x  3 clara  staff        96 Jan 15 17:58 __pycache__
# drwxr-xr-x@ 6 clara  staff       192 Jan 15 17:16 data
# -rw-r--r--  1 clara  staff      4008 Jan 15 14:48 environment.yml
# -rw-r--r--  1 clara  staff      1717 Jan 15 12:55 functions.py
# -rw-r--r--  1 clara  staff      2189 Jan 15 17:52 main.py
# -rw-r--r--  1 clara  staff     43867 Jan 15 18:00 pancreaticlipase.zip
# -rw-r--r--  1 clara  staff    296419 Jan 15 18:00 pancreaticlipase_01_bioactivity_data_raw.csv
# -rw-r--r--  1 clara  staff     43257 Jan 15 18:00 pancreaticlipase_02_bioactivity_data_preprocessed.csv
# -rw-r--r--  1 clara  staff     47696 Jan 15 18:00 pancreaticlipase_03_bioactivity_data_curated.csv
# drwxr-xr-x@ 2 clara  staff        64 Jan 15 17:16 plots
# -rw-r--r--  1 clara  staff      2593 Jan 15 13:02 single_file_code.py

# %% [markdown]
# ---
