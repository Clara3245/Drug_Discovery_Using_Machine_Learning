# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery**
#
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# I will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (0.10.9)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.18.4->chembl_webresource_client) (2019.11.28)
# Requirement already satisfied: attrs>=21.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-cache~=1.2->chembl_webresource_client) (24.3.0)
# Requirement already satisfied: cattrs>=22.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Requirement already satisfied: url-normalize>=1.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /Users/clara/Library/Python/3.8/lib/python/site-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.14.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for pancreas**

# %%
# Target search for pancreas
target = new_client.target
target_query = target.search('pancreas')
targets = pd.DataFrame.from_dict(target_query)
targets.head(10)
# Out:
#   cross_references           organism                       pref_name  score  \
# 0               []       Mus musculus                        Pancreas   19.0
# 1               []  Rattus norvegicus                        Pancreas   19.0
# 2               []       Homo sapiens              Carboxypeptidase B   18.0
# 3               []       Homo sapiens                    Kallikrein 1   17.0
# 4               []       Homo sapiens  Protein disulfide-isomerase A2   17.0
# 5               []       Homo sapiens                        Tryptase    6.0
# 6               []       Homo sapiens                         Trypsin    6.0
# 7               []         Sus scrofa             Pancreatic elastase    6.0
# 8               []       Homo sapiens              Thrombin & trypsin    6.0
# 9               []       Homo sapiens    Coagulation factor VII and X    6.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613587
# 1               False     CHEMBL613650
# 2               False       CHEMBL2552
# 3               False       CHEMBL2319
# 4               False    CHEMBL4739853
# 5               False    CHEMBL2095193
# 6               False    CHEMBL2095204
# 7               False    CHEMBL2096984
# 8               False    CHEMBL2096988
# 9               False    CHEMBL2111412
#
#                                    target_components        target_type  \
# 0                                                 []             TISSUE
# 1                                                 []             TISSUE
# 2  [{'accession': 'P15086', 'component_descriptio...     SINGLE PROTEIN
# 3  [{'accession': 'P06870', 'component_descriptio...     SINGLE PROTEIN
# 4  [{'accession': 'Q13087', 'component_descriptio...     SINGLE PROTEIN
# 5  [{'accession': 'Q9BZJ3', 'component_descriptio...     PROTEIN FAMILY
# 6  [{'accession': 'P07477', 'component_descriptio...     PROTEIN FAMILY
# 7  [{'accession': 'P08419', 'component_descriptio...     PROTEIN FAMILY
# 8  [{'accession': 'P00734', 'component_descriptio...  SELECTIVITY GROUP
# 9  [{'accession': 'P00742', 'component_descriptio...  SELECTIVITY GROUP
#
#    tax_id
# 0   10090
# 1   10116
# 2    9606
# 3    9606
# 4    9606
# 5    9606
# 6    9606
# 7    9823
# 8    9606
# 9    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human pancreas* (seventh entry)**

# %% [markdown]
# We will assign the seventhth entry (which corresponds to the target protein, *Human Pancreatic lipase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL2095204'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Pancreatic lipase* (CHEMBL2095204) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target)

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 2217                                               None             None
# 2218                                               None             None
# 2219  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2220                                               None             None
# 2221                                               None             None
#
#       activity_id                                activity_properties  \
# 0           34309                                                 []
# 1           34315                                                 []
# 2           37941                                                 []
# 3           40292                                                 []
# 4           40298                                                 []
# ...           ...                                                ...
# 2217     25655408  [{'comments': None, 'relation': '=', 'result_f...
# 2218     25655409  [{'comments': None, 'relation': '=', 'result_f...
# 2219     25702957                                                 []
# 2220     25702988  [{'comments': None, 'relation': '=', 'result_f...
# 2221     25702989  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL815474             Binding affinity against human trypsin
# 1       CHEMBL815474             Binding affinity against human trypsin
# 2       CHEMBL815474             Binding affinity against human trypsin
# 3       CHEMBL815474             Binding affinity against human trypsin
# 4       CHEMBL815474             Binding affinity against human trypsin
# ...              ...                                                ...
# 2217   CHEMBL5372071  Inhibition of trypsin (unknown origin) at 50 u...
# 2218   CHEMBL5372071  Inhibition of trypsin (unknown origin) at 50 u...
# 2219   CHEMBL5385448  Binding affinity to trypsin (unknown origin) a...
# 2220   CHEMBL5385455  Inhibition of human recombinant trypsin using ...
# 2221   CHEMBL5385455  Inhibition of human recombinant trypsin using ...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 2217          B                    None                   None  BAO_0000201
# 2218          B                    None                   None  BAO_0000201
# 2219          B                    None                   None  BAO_0000192
# 2220          B                    None                   None  BAO_0000190
# 2221          B                    None                   None  BAO_0000190
#
#       ... target_organism target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens          Trypsin          9606       None  None
# 1     ...    Homo sapiens          Trypsin          9606       None  None
# 2     ...    Homo sapiens          Trypsin          9606       None  None
# 3     ...    Homo sapiens          Trypsin          9606       None  None
# 4     ...    Homo sapiens          Trypsin          9606       None  None
# ...   ...             ...              ...           ...        ...   ...
# 2217  ...    Homo sapiens          Trypsin          9606       None  None
# 2218  ...    Homo sapiens          Trypsin          9606       None  None
# 2219  ...    Homo sapiens          Trypsin          9606       None  None
# 2220  ...    Homo sapiens          Trypsin          9606       None  None
# 2221  ...    Homo sapiens          Trypsin          9606       None  None
#
#       type units    uo_units upper_value    value
# 0     IC50    uM  UO_0000065        None     10.0
# 1     IC50    uM  UO_0000065        None     10.0
# 2     IC50    uM  UO_0000065        None     10.0
# 3     IC50    uM  UO_0000065        None     10.0
# 4     IC50    uM  UO_0000065        None     10.0
# ...    ...   ...         ...         ...      ...
# 2217   INH     %  UO_0000187        None      5.0
# 2218   INH     %  UO_0000187        None      5.0
# 2219    Ki    uM  UO_0000065        None     0.18
# 2220  IC50    uM  UO_0000065        None     30.0
# 2221  IC50    nM  UO_0000065        None  30000.0
#
# [2222 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('pancreaticlipase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /var/folders/9t/1rlf9b_96lsfrsxt8gwyny980000gn/T/ipykernel_34708/3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 2217                                               None             None
# 2218                                               None             None
# 2219  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2220                                               None             None
# 2221                                               None             None
#
#       activity_id                                activity_properties  \
# 0           34309                                                 []
# 1           34315                                                 []
# 2           37941                                                 []
# 3           40292                                                 []
# 4           40298                                                 []
# ...           ...                                                ...
# 2217     25655408  [{'comments': None, 'relation': '=', 'result_f...
# 2218     25655409  [{'comments': None, 'relation': '=', 'result_f...
# 2219     25702957                                                 []
# 2220     25702988  [{'comments': None, 'relation': '=', 'result_f...
# 2221     25702989  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL815474             Binding affinity against human trypsin
# 1       CHEMBL815474             Binding affinity against human trypsin
# 2       CHEMBL815474             Binding affinity against human trypsin
# 3       CHEMBL815474             Binding affinity against human trypsin
# 4       CHEMBL815474             Binding affinity against human trypsin
# ...              ...                                                ...
# 2217   CHEMBL5372071  Inhibition of trypsin (unknown origin) at 50 u...
# 2218   CHEMBL5372071  Inhibition of trypsin (unknown origin) at 50 u...
# 2219   CHEMBL5385448  Binding affinity to trypsin (unknown origin) a...
# 2220   CHEMBL5385455  Inhibition of human recombinant trypsin using ...
# 2221   CHEMBL5385455  Inhibition of human recombinant trypsin using ...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 2217          B                    None                   None  BAO_0000201
# 2218          B                    None                   None  BAO_0000201
# 2219          B                    None                   None  BAO_0000192
# 2220          B                    None                   None  BAO_0000190
# 2221          B                    None                   None  BAO_0000190
#
#       ... target_organism target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens          Trypsin          9606       None  None
# 1     ...    Homo sapiens          Trypsin          9606       None  None
# 2     ...    Homo sapiens          Trypsin          9606       None  None
# 3     ...    Homo sapiens          Trypsin          9606       None  None
# 4     ...    Homo sapiens          Trypsin          9606       None  None
# ...   ...             ...              ...           ...        ...   ...
# 2217  ...    Homo sapiens          Trypsin          9606       None  None
# 2218  ...    Homo sapiens          Trypsin          9606       None  None
# 2219  ...    Homo sapiens          Trypsin          9606       None  None
# 2220  ...    Homo sapiens          Trypsin          9606       None  None
# 2221  ...    Homo sapiens          Trypsin          9606       None  None
#
#       type units    uo_units upper_value    value
# 0     IC50    uM  UO_0000065        None     10.0
# 1     IC50    uM  UO_0000065        None     10.0
# 2     IC50    uM  UO_0000065        None     10.0
# 3     IC50    uM  UO_0000065        None     10.0
# 4     IC50    uM  UO_0000065        None     10.0
# ...    ...   ...         ...         ...      ...
# 2217   INH     %  UO_0000187        None      5.0
# 2218   INH     %  UO_0000187        None      5.0
# 2219    Ki    uM  UO_0000065        None     0.18
# 2220  IC50    uM  UO_0000065        None     30.0
# 2221  IC50    nM  UO_0000065        None  30000.0
#
# [1770 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1610

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 2198  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2199  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2219  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2220                                               None             None
# 2221                                               None             None
#
#       activity_id                                activity_properties  \
# 0           34309                                                 []
# 1           34315                                                 []
# 2           37941                                                 []
# 3           40292                                                 []
# 4           40298                                                 []
# ...           ...                                                ...
# 2198     25655384  [{'comments': None, 'relation': '=', 'result_f...
# 2199     25655385  [{'comments': None, 'relation': '=', 'result_f...
# 2219     25702957                                                 []
# 2220     25702988  [{'comments': None, 'relation': '=', 'result_f...
# 2221     25702989  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL815474             Binding affinity against human trypsin
# 1       CHEMBL815474             Binding affinity against human trypsin
# 2       CHEMBL815474             Binding affinity against human trypsin
# 3       CHEMBL815474             Binding affinity against human trypsin
# 4       CHEMBL815474             Binding affinity against human trypsin
# ...              ...                                                ...
# 2198   CHEMBL5372066  Inhibition of trypsin (unknown origin) assesse...
# 2199   CHEMBL5372066  Inhibition of trypsin (unknown origin) assesse...
# 2219   CHEMBL5385448  Binding affinity to trypsin (unknown origin) a...
# 2220   CHEMBL5385455  Inhibition of human recombinant trypsin using ...
# 2221   CHEMBL5385455  Inhibition of human recombinant trypsin using ...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 2198          B                    None                   None  BAO_0000193
# 2199          B                    None                   None  BAO_0000193
# 2219          B                    None                   None  BAO_0000192
# 2220          B                    None                   None  BAO_0000190
# 2221          B                    None                   None  BAO_0000190
#
#       ... target_organism target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens          Trypsin          9606       None  None
# 1     ...    Homo sapiens          Trypsin          9606       None  None
# 2     ...    Homo sapiens          Trypsin          9606       None  None
# 3     ...    Homo sapiens          Trypsin          9606       None  None
# 4     ...    Homo sapiens          Trypsin          9606       None  None
# ...   ...             ...              ...           ...        ...   ...
# 2198  ...    Homo sapiens          Trypsin          9606       None  None
# 2199  ...    Homo sapiens          Trypsin          9606       None  None
# 2219  ...    Homo sapiens          Trypsin          9606       None  None
# 2220  ...    Homo sapiens          Trypsin          9606       None  None
# 2221  ...    Homo sapiens          Trypsin          9606       None  None
#
#        type units    uo_units upper_value    value
# 0      IC50    uM  UO_0000065        None     10.0
# 1      IC50    uM  UO_0000065        None     10.0
# 2      IC50    uM  UO_0000065        None     10.0
# 3      IC50    uM  UO_0000065        None     10.0
# 4      IC50    uM  UO_0000065        None     10.0
# ...     ...   ...         ...         ...      ...
# 2198  Ratio  None        None        None      1.0
# 2199  Ratio  None        None        None      1.0
# 2219     Ki    uM  UO_0000065        None     0.18
# 2220   IC50    uM  UO_0000065        None     30.0
# 2221   IC50    nM  UO_0000065        None  30000.0
#
# [1610 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL337921  Cc1cc(NC(=O)Cc2ccc3[nH]c(-c4ccc(Cl)s4)nc3c2)cc...
# 1          CHEMBL340500  Cc1cc(NC(=O)Cc2ccc3[nH]c(-c4ccc(Cl)s4)nc3c2)cc...
# 2          CHEMBL124846  O=C(Cc1ccc2[nH]c(-c3ccc(Cl)s3)nc2c1)Nc1ccc(N2C...
# 3          CHEMBL331231  CS(=O)(=O)c1ccccc1-c1ccc(NC(=O)Cc2ccc3[nH]c(-c...
# 4          CHEMBL124705  O=C(Cc1ccc2[nH]c(-c3ccc(Cl)s3)nc2c1)Nc1ccc(N2C...
# ...                 ...                                                ...
# 2198      CHEMBL5422704  CC(C)(C)OC(=O)NCCCC[C@H](NC(=O)OCC1c2ccccc2-c2...
# 2199      CHEMBL5414967  CC(C)(C)OC(=O)n1cc(C[C@H](NC(=O)OCC2c3ccccc3-c...
# 2219      CHEMBL3901198  CCCc1c(-c2csc(-c3cc(C(=N)N)sc3SC)n2)cnn1-c1ccccn1
# 2220      CHEMBL5431053          Cc1ccccc1C(=O)N1CCN(c2ccc3c(N)nncc3c2)CC1
# 2221      CHEMBL5417464  Cc1cc([C@H]2CN(c3cc(F)c4c(N)nncc4c3)CCN2c2cccc...
#
#      standard_value
# 0           10000.0
# 1           10000.0
# 2           10000.0
# 3           10000.0
# 4           10000.0
# ...             ...
# 2198            1.0
# 2199            1.0
# 2219          180.0
# 2220        30000.0
# 2221        30000.0
#
# [1610 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('pancreaticlipase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('pancreaticlipase_02_bioactivity_data_preprocessed.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'acetylcholinesterase_02_bioactivity_data_preprocessed.csv'

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL337921  Cc1cc(NC(=O)Cc2ccc3[nH]c(-c4ccc(Cl)s4)nc3c2)cc...
# 1          CHEMBL340500  Cc1cc(NC(=O)Cc2ccc3[nH]c(-c4ccc(Cl)s4)nc3c2)cc...
# 2          CHEMBL124846  O=C(Cc1ccc2[nH]c(-c3ccc(Cl)s3)nc2c1)Nc1ccc(N2C...
# 3          CHEMBL331231  CS(=O)(=O)c1ccccc1-c1ccc(NC(=O)Cc2ccc3[nH]c(-c...
# 4          CHEMBL124705  O=C(Cc1ccc2[nH]c(-c3ccc(Cl)s3)nc2c1)Nc1ccc(N2C...
# ...                 ...                                                ...
# 1605      CHEMBL5422704  CC(C)(C)OC(=O)NCCCC[C@H](NC(=O)OCC1c2ccccc2-c2...
# 1606      CHEMBL5414967  CC(C)(C)OC(=O)n1cc(C[C@H](NC(=O)OCC2c3ccccc3-c...
# 1607      CHEMBL3901198  CCCc1c(-c2csc(-c3cc(C(=N)N)sc3SC)n2)cnn1-c1ccccn1
# 1608      CHEMBL5431053          Cc1ccccc1C(=O)N1CCN(c2ccc3c(N)nncc3c2)CC1
# 1609      CHEMBL5417464  Cc1cc([C@H]2CN(c3cc(F)c4c(N)nncc4c3)CCN2c2cccc...
#
#       standard_value     class
# 0            10000.0  inactive
# 1            10000.0  inactive
# 2            10000.0  inactive
# 3            10000.0  inactive
# 4            10000.0  inactive
# ...              ...       ...
# 1605             1.0    active
# 1606             1.0    active
# 1607           180.0    active
# 1608         30000.0  inactive
# 1609         30000.0  inactive
#
# [1610 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('pancreaticlipase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip pancreaticlipase.zip *.csv
# Out:
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 84%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 85%)
#   adding: pancreas_07_bioactivity_data_raw.csv (deflated 92%)
#   adding: pancreatic_lipase_07_bioactivity_data_raw.csv (deflated 92%)
#   adding: pancreaticlipase_01_bioactivity_data_raw.csv (deflated 92%)
#   adding: pancreaticlipase_02_bioactivity_data_preprocessed.csv (deflated 84%)
#   adding: pancreaticlipase_03_bioactivity_data_curated.csv (deflated 85%)

# %%
! ls -l
# Out:
# total 11808
# -rw-r--r--  1 clara  staff   101536 Jan 15 09:32 CDD_ML_Part_1_Acetylcholinesterase_Bioactivity_Data_Concised.ipynb
# -rw-r--r--  1 clara  staff       25 Jan 14 15:12 README.md
# -rw-r--r--  1 clara  staff   256551 Jan 15 09:24 acetylcholinesterase.zip
# -rw-r--r--  1 clara  staff   150266 Jan 15 09:24 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r--  1 clara  staff   165700 Jan 15 09:24 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r--  1 clara  staff      804 Jan 15 08:33 main.py
# -rw-r--r--  1 clara  staff  1257563 Jan 15 08:33 pancreas_07_bioactivity_data_raw.csv
# -rw-r--r--  1 clara  staff  1257563 Jan 15 09:24 pancreatic_lipase_07_bioactivity_data_raw.csv
# -rw-r--r--  1 clara  staff   410203 Jan 15 09:32 pancreaticlipase.zip
# -rw-r--r--  1 clara  staff  1257563 Jan 15 09:32 pancreaticlipase_01_bioactivity_data_raw.csv
# -rw-r--r--  1 clara  staff   150266 Jan 15 09:32 pancreaticlipase_02_bioactivity_data_preprocessed.csv
# -rw-r--r--  1 clara  staff   165700 Jan 15 09:32 pancreaticlipase_03_bioactivity_data_curated.csv

# %% [markdown]
# ---
